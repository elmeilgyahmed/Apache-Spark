# %%
# !pip install riotwatcher
# Out:
# ...
#      |████████████████████████████████| 56 kB 1.7 MB/s
# ...

# %%
from riotwatcher import LolWatcher,ApiError
watcher=LolWatcher('RGAPI-3a40a643-54e7-4635-84ca-ba4d7377ca59')
br_region =  'br1'
euw_region =  'euw1'
na_region =  'na1'
ru_region =  'ru'
oc_region =  'oc1'
eun_region = 'EUN1'

# For reference the distribuation of eune region https://www.leagueofgraphs.com/rankings/rank-distribution/eune

# [Diamond 1.7%     Platinum 12%    Gold 28%    Silver 35%    Bronze 19%    Iron 2.2%]
# for 20 summoner [1D 2P 5G 7S 4B 1I]
# use this endpoint to get summoner Id, name [https://developer.riotgames.com/apis#league-v4/GET_getLeagueEntries]

'''
1D  ----->  ["Coldburns" ,"SvxCb-17C_XGaQQp8CEYHiwxHp8yi2ZbJggmrQs30OKg", "division l" , "RANKED_SOLO_5x5"]
2P  ----->  ["WalkingDepresion" ,"4PC8SMgFUpHKeQcvmgocz8j7vnsTVhQzLOh9JhMLH36d","Keruze","mThRleQbtzIoMbGlx4BNfWldDll8dHYmr1Y8QCST6na8","division ll" , "RANKED_SOLO_5x5"]
5G  ----->  [ "Pepsie","1x2oYV8dTev4_N6BXqdZYIDDxW_3xo6lr_S8A-vYk6ev","Tanthalas","gepYqEwQBgxkSkDWoZvWLKaXn8T7_lTHzpQoBCTAW0k","theflyingpenguin",
              "NIiY6V8rQGypMuMai5e4PBT03gJ0tj_PnuhAYBzugOOs","Gorki","X9DyHnMOOqpJnhnO_Zn81lkUYFKm4Ne6TUF8Swu6D6HW","Ostoba Tuk","VlZwnFPKn2znQ07dTLQUB1urfvN0CYapDfFBjlisWvC4",
              "division lll" ,"RANKED_SOLO_5x5"]
7S  ----->  ["Firann","7t0PPcosw3Zg1RwKTAErUhD2jYM2JloN7hcFZNfCQqnq","RenektonR","btWlyBi_CCsICvIWODpQO35PtDCV1ffkEe5_FAy42TZA","division lV" ,"RANKED_FLEX_SR"]
            ["PaT12oL","aIn1vUcuQFsNtPzihKuwcEUZDAJfnZbXtHgGedYFok5L","necromancer13","kqrOkg_Z7E6n7Dei8Og8E64-pigZrQddTdsA9lVy5EkT","division l","RANKED_SOLO_5x5"]
            ["Jedar Wex","Exe5JBvlIQocKUsSmySyTCgSoZJMjKjALKd4CeaNJmE","Radinović","yv8RcLoW1jb1LQxzQKBkMZsU0DThq1mBm3d64bKyq9oa","Wester Sylwester","nIGFzkkVsZOlqQZXzwqaoNX28IWSe9FX7bS0DwxEFipg","division ll","RANKED_FLEX_SR"]
4B  ----->  ["ZiMa","1DbEGpe1cQaD7VhZW0SERYlx-P8SMAcaxwkZF3IQfow","WalkiM","rjP6nECg9dFiAnnpOAxw_y_-v0hbYHvVXN96JNUntP8-","division lll","RANKED_SOLO_5x5"]
            ["haveno","_8JXmNRxAmnVkh8lxDSyzi-nuBTqS7lglswLe0TLf_Bk","Twiztdfate","FGb1QDbtz_2Njt_WlhqGKSZ-SSPqnL7ffa-pWt8QEBEj","division lV","RANKED_FLEX_SR"]

      "Exe5JBvlIQocKUsSmySyTCgSoZJMjKjALKd4CeaNJmE","yv8RcLoW1jb1LQxzQKBkMZsU0DThq1mBm3d64bKyq9oa",
      "nIGFzkkVsZOlqQZXzwqaoNX28IWSe9FX7bS0DwxEFipg","1DbEGpe1cQaD7VhZW0SERYlx-P8SMAcaxwkZF3IQfow",
      "rjP6nECg9dFiAnnpOAxw_y_-v0hbYHvVXN96JNUntP8-","_8JXmNRxAmnVkh8lxDSyzi-nuBTqS7lglswLe0TLf_Bk",
      "FGb1QDbtz_2Njt_WlhqGKSZ-SSPqnL7ffa-pWt8QEBEj","2fnZSn_WFbiEpWJcmQstdvzCX6_rfzZd0rrJby9GW_7t"]
'''
# Out:
# '\n1D  ----->  ["Coldburns" ,"SvxCb-17C_XGaQQp8CEYHiwxHp8yi2ZbJggmrQs30OKg", "division l" , "RANKED_SOLO_5x5"]\n2P  ----->  ["WalkingDepresion" ,"4PC8SMgFUpHKeQcvmgocz8j7vnsTVhQzLOh9JhMLH36d","Keruze","mThRleQbtzIoMbGlx4BNfWldDll8dHYmr1Y8QCST6na8","division ll" , "RANKED_SOLO_5x5"]\n5G  ----->  [ "Pepsie","1x2oYV8dTev4_N6BXqdZYIDDxW_3xo6lr_S8A-vYk6ev","Tanthalas","gepYqEwQBgxkSkDWoZvWLKaXn8T7_lTHzpQoBCTAW0k","theflyingpenguin",\n              "NIiY6V8rQGypMuMai5e4PBT03gJ0tj_PnuhAYBzugOOs","Gorki","X9DyHnMOOqpJnhnO_Zn81lkUYFKm4Ne6TUF8Swu6D6HW","Ostoba Tuk","VlZwnFPKn2znQ07dTLQUB1urfvN0CYapDfFBjlisWvC4",\n              "division lll" ,"RANKED_SOLO_5x5"]\n7S  ----->  ["Firann","7t0PPcosw3Zg1RwKTAErUhD2jYM2JloN7hcFZNfCQqnq","RenektonR","btWlyBi_CCsICvIWODpQO35PtDCV1ffkEe5_FAy42TZA","division lV" ,"RANKED_FLEX_SR"]\n            ["PaT12oL","aIn1vUcuQFsNtPzihKuwcEUZDAJfnZbXtHgGedYFok5L","necromancer13","kqrOkg_Z7E6n7Dei8Og8E64-pigZrQddTdsA9lVy5EkT","division l","RANKED_SOLO_5x5"]\n         
# ...

# %%
 ids=["SvxCb-17C_XGaQQp8CEYHiwxHp8yi2ZbJggmrQs30OKg","4PC8SMgFUpHKeQcvmgocz8j7vnsTVhQzLOh9JhMLH36d",
      "mThRleQbtzIoMbGlx4BNfWldDll8dHYmr1Y8QCST6na8","1x2oYV8dTev4_N6BXqdZYIDDxW_3xo6lr_S8A-vYk6ev",
      "gepYqEwQBgxkSkDWoZvWLKaXn8T7_lTHzpQoBCTAW0k","NIiY6V8rQGypMuMai5e4PBT03gJ0tj_PnuhAYBzugOOs",
      "X9DyHnMOOqpJnhnO_Zn81lkUYFKm4Ne6TUF8Swu6D6HW","VlZwnFPKn2znQ07dTLQUB1urfvN0CYapDfFBjlisWvC4",
      "7t0PPcosw3Zg1RwKTAErUhD2jYM2JloN7hcFZNfCQqnq","btWlyBi_CCsICvIWODpQO35PtDCV1ffkEe5_FAy42TZA",
      "aIn1vUcuQFsNtPzihKuwcEUZDAJfnZbXtHgGedYFok5L","kqrOkg_Z7E6n7Dei8Og8E64-pigZrQddTdsA9lVy5EkT",
      "Exe5JBvlIQocKUsSmySyTCgSoZJMjKjALKd4CeaNJmE","yv8RcLoW1jb1LQxzQKBkMZsU0DThq1mBm3d64bKyq9oa",
      "nIGFzkkVsZOlqQZXzwqaoNX28IWSe9FX7bS0DwxEFipg","1DbEGpe1cQaD7VhZW0SERYlx-P8SMAcaxwkZF3IQfow",
      "rjP6nECg9dFiAnnpOAxw_y_-v0hbYHvVXN96JNUntP8-","_8JXmNRxAmnVkh8lxDSyzi-nuBTqS7lglswLe0TLf_Bk",
      "FGb1QDbtz_2Njt_WlhqGKSZ-SSPqnL7ffa-pWt8QEBEj","2fnZSn_WFbiEpWJcmQstdvzCX6_rfzZd0rrJby9GW_7t"]
names=["Coldburns","WalkingDepresion","Keruze","Pepsie","Tanthalas",
       "theflyingpenguin","Gorki","Ostoba Tuk","Firann","RenektonR",
       "PaT12oL","necromancer13","Jedar Wex","Radinović","Wester Sylwester",
       "ZiMa","WalkiM","haveno","Twiztdfate","Luottopakki"]
def summoner_by_name(region,name):
  return watcher.summoner.by_name(region,name)
def get_match(match_id):
    return watcher.match.by_id("europe",match_id) 
#print(summoner_by_name(eun_region,names[0])['puuid'])

# %%
players_puuid=[]
for na in names:
  players_puuid.append(summoner_by_name(eun_region,na)['puuid'])

# %%
matchlist=[]
for pu in players_puuid:
    matchlist.append(watcher.match.matchlist_by_puuid("europe",pu,count=100))

# %%
total_matches=0
for i in range(20):
  total_matches=total_matches+len(matchlist[i])
print(total_matches)
# Out:
# 1828

# %%
import json
'''
Don't run it again we already have this cell output in ahmed kamal's drive 
'''
'''
with open('data', 'w') as f:
  for match in matchlist:
    for each_sum in match:
      f.write(json.dumps(get_match(each_sum))+"\n")
'''

# %%
# mount it
from google.colab import drive
drive.mount('/content/drive')
# copy it there
#!cp data /content/drive/MyDrive
# Out:
# Mounted at /content/drive

# %%
import json 
all_match = []
with open("drive/MyDrive/data") as f:
    for jsonObj in f:
        studentDict = json.loads(jsonObj)
        all_match.append(studentDict)

# %%
new_part_puuid=[]
for match in range(len(all_match)):
  new_part_puuid.append(all_match[match]['metadata']['participants'])

# %%
print("new puuids for partcipants:",len(new_part_puuid)*9)
# Out:
# new puuids for partcipants: 9720

# %%
new_matchlist=[]
for pu in new_part_puuid:
  for p in pu:
    new_matchlist.append(watcher.match.matchlist_by_puuid("europe",p,count=10))

# %%
with open("new_list.txt", "w") as fp:
  json.dump(new_matchlist, fp)

'''
with open("new_list.txt", "r") as fp:
     b = json.load(fp)
'''

# %%
from google.colab import files
files.download('/content/new_list.txt')

# %%
with open('new_list.txt','r') as f:
  b=json.load(f)

# %%
print("number of matches :",len(b)*10)
# Out:
# number of matches : 71990

# %%
with open('extra_data', 'w') as f:
    for match in b[0:320]:
      for id in match :
        f.write(json.dumps(get_match(id))+"\n")

# %%
# copy it there
# !cp one_big /content/drive/MyDrive
